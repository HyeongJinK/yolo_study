# %%
pip install ultralytics

# %%
yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# # 여기서 부터 시작

# %%
# !yolo train \
data=/Users/hyeongjinkim/Desktop/project/ai/yolov5/custom/test/test2.yaml \
model=yolov8n.pt \
epochs=10 \
lr0=0.01 \
project=/Users/hyeongjinkim/Desktop/project/ai/yolov5/custom/model \
name=yolov8n \
device=mps

# %% [markdown]
# ## 디텍팅

# %%
# !yolo detect predict \
model=/Users/hyeongjinkim/Desktop/project/ai/yolov5/custom/model/train4/weights/best.pt \
source='/Users/hyeongjinkim/Desktop/project/ai/yolov5/source' \
conf=0.5

# %%
# !yolo detect predict \
model=/Users/hyeongjinkim/Desktop/project/ai/yolov5/custom/model/yolov8s2/weights/best.pt \
source='/Users/hyeongjinkim/Desktop/project/ai/yolov5/source' \
conf=0.7

# %% [markdown]
# # CUP

# %%
# !yolo train \
data=/Users/hyeongjinkim/dataset/cup/cup.yaml \
model=yolov8m.pt \
epochs=30 \
batch=8 \
lr0=0.01 \
project=/Users/hyeongjinkim/dataset/cup/model \
name=yolov8m \
device=cpu

# %% [markdown]
# ## 디텍팅 테스트

# %%
# !yolo detect predict \
model=/Users/hyeongjinkim/dataset/cup/model/yolov8m_30/weights/best.pt \
source='/Users/hyeongjinkim/dataset/CUPTEST' \
conf=0.85

# %% [markdown]
# # 오일머니

# %%
# !yolo train \
data=/Users/hyeongjinkim/dataset/om/om.yaml \
model=yolov8s.pt \
epochs=100 \
batch=16 \
lr0=0.01 \
project=/Users/hyeongjinkim/dataset/om/model \
name=om_s \
device=mps
#resume=True \
#model=/Users/hyeongjinkim/dataset/om/model/yolov8s3/weights/last.pt \

# %%
# !yolo detect predict \
model=/Users/hyeongjinkim/dataset/om2/model/om_s/weights/best.pt \
source='/Users/hyeongjinkim/dataset/CUPTEST' \
conf=0.7

# %%
# !yolo train model=/Users/hyeongjinkim/dataset/om/model/yolov8s3/weights/last.pt resume=True

# %% [markdown]
# ## 박스 빈공간 최대한 없앤 데이터 훈련

# %%
# !yolo train \
data=/Users/hyeongjinkim/dataset/om2/om.yaml \
model=yolov8s.pt \
epochs=100 \
batch=16 \
lr0=0.01 \
project=/Users/hyeongjinkim/dataset/om2/model \
name=om_s \
device=mps
#resume=True \
#model=/Users/hyeongjinkim/dataset/om/model/yolov8s3/weights/last.pt \
# Out:
# New https://pypi.org/project/ultralytics/8.0.230 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.229 🚀 Python-3.11.5 torch-2.1.2 MPS (Apple M1 Pro)
# ...

# %%
# !yolo detect predict \
model=/Users/hyeongjinkim/dataset/om2/model/om_s/weights/best.pt \
source='/Users/hyeongjinkim/dataset/CUPTEST' \
conf=0.7
# Out:
# Ultralytics YOLOv8.0.229 🚀 Python-3.11.5 torch-2.1.2 CPU (Apple M1 Pro)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/24 /Users/hyeongjinkim/dataset/CUPTEST/00339026-5893-4652-baff-095cf78fa5a5.png: 480x640 1 PET, 78.1ms
# image 2/24 /Users/hyeongjinkim/dataset/CUPTEST/29c540f7-bbf4-46f6-bf40-42812ac9e95a.png: 480x640 1 PET, 1 CAN, 72.2ms
# image 3/24 /Users/hyeongjinkim/dataset/CUPTEST/39dcfd16-8c71-4777-8feb-7bb592345028.png: 480x640 1 PET, 1 CAN, 75.2ms
# image 4/24 /Users/hyeongjinkim/dataset/CUPTEST/47dde479-67ac-46af-8282-77ec84fa0285.png: 480x640 (no detections), 74.8ms
# image 5/24 /Users/hyeongjinkim/dataset/CUPTEST/4efdfc1c-2909-47f2-a379-d5f19dfd42ab.png: 480x640 1 PET, 1 CAN, 75.5ms
# image 6/24 /Users/hyeongjinkim/dataset/CUPTEST/53e1c9b4-2b1a-4043-8d4d-aeb5cac1c01b.png: 480x640 1 PET, 65.9ms
# image 7/24 /Users/hyeongjinkim/dataset/CUPTEST/6466805c-124f-424e-af9b-b6d020cd94d1.png: 480x640 3 PETs, 1 CAN, 73.7ms
# ...

# %% [markdown]
# ## 추가학습 테스트

# %%
# !yolo train \
data=/Users/hyeongjinkim/dataset/om3/om.yaml \
model=/Users/hyeongjinkim/dataset/om2/model/om_s/weights/best.pt \
epochs=100 \
batch=16 \
lr0=0.01 \
project=/Users/hyeongjinkim/dataset/om3/model \
name=om_s \
device=mps
#resume=True \
#model=/Users/hyeongjinkim/dataset/om/model/yolov8s3/weights/last.pt \
# Out:
# New https://pypi.org/project/ultralytics/8.0.230 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.229 🚀 Python-3.11.5 torch-2.1.2 MPS (Apple M1 Pro)
# ...
